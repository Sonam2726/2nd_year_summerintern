# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col

# %%
spark = SparkSession.builder.appName("SalesDataFrameAnalysis").getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/15 13:44:26 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/06/15 13:44:39 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %%
df = spark.read.csv("sales.csv",header=True)

# %%
df.show()
# Out:
# +----------+------------+-----------+------+
# |product_id|product_name|   category| sales|
# +----------+------------+-----------+------+
# |       101|      Laptop|Electronics|150000|
# |       102|      Mobile|Electronics| 95000|
# |       103|          TV|Electronics|120000|
# |       104|       Chair|  Furniture| 30000|
# |       105|       Table|  Furniture| 45000|
# |       106|        Sofa|  Furniture| 80000|
# |       107|  Headphones|Electronics| 25000|
# |       108|         Bed|  Furniture| 90000|
# +----------+------------+-----------+------+

# %%
print(" Products Sorted by Sales ")
sorted_df = df.orderBy(col("sales").desc())
sorted_df.show()
sorted_df.write.mode("overwrite").csv("output/sorted_df",header=True)
# Out:
#  Products Sorted by Sales
# +----------+------------+-----------+------+
# |product_id|product_name|   category| sales|
# +----------+------------+-----------+------+
# |       102|      Mobile|Electronics| 95000|
# |       108|         Bed|  Furniture| 90000|
# |       106|        Sofa|  Furniture| 80000|
# |       105|       Table|  Furniture| 45000|
# |       104|       Chair|  Furniture| 30000|
# |       107|  Headphones|Electronics| 25000|
# |       101|      Laptop|Electronics|150000|
# |       103|          TV|Electronics|120000|
# +----------+------------+-----------+------+

# %%
print(" Top 3 Products ")
top3 = sorted_df.limit(3)
top3.show()
top3.write.mode("overwrite").csv("output/top3",header=True)
# Out:
#  Top 3 Products
# +----------+------------+-----------+-----+
# |product_id|product_name|   category|sales|
# +----------+------------+-----------+-----+
# |       102|      Mobile|Electronics|95000|
# |       108|         Bed|  Furniture|90000|
# |       106|        Sofa|  Furniture|80000|
# +----------+------------+-----------+-----+

# %%
print(" Products with Sales > 80000")
high_sales = df.filter(col("sales") > 80000)
high_sales.show()
high_sales.write.mode("overwrite").csv("output/high_sales",header=True)
# Out:
#  Products with Sales > 80000
# +----------+------------+-----------+------+
# |product_id|product_name|   category| sales|
# +----------+------------+-----------+------+
# |       101|      Laptop|Electronics|150000|
# |       102|      Mobile|Electronics| 95000|
# |       103|          TV|Electronics|120000|
# |       108|         Bed|  Furniture| 90000|
# +----------+------------+-----------+------+

# %%
spark.stop()
